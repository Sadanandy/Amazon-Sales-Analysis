# %%
import pandas as pd  # For data manipulation
import numpy as np  # For numerical operations

# %%
# Load the Dataset
df=pd.read_csv("Amazon-Products.csv")

# %%
# To verify the Dataset
# Check First few rows
df.head(180)
# Out:
#      Unnamed: 0                                               name  \
# 0             0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1             1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2             2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3             3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4             4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
# ..          ...                                                ...
# 175         175  Daikin 2.02 Ton 4 Star, Inverter Split AC (Cop...
# 176         176  Carrier 1 Ton 3 Star Fixed Speed Window AC(Cop...
# 177         177  Hisense 1.0 Ton 5 Star Inverter Split AC (Copp...
# 178         178  Daikin 1.8 Ton 5 Star Inverter Split AC (Coppe...
# 179         179  Blue Star 1.5 Ton 3 Star Inverter Window AC (C...
#
#     main_category      sub_category  \
# 0      appliances  Air Conditioners
# 1      appliances  Air Conditioners
# 2      appliances  Air Conditioners
# 3      appliances  Air Conditioners
# 4      appliances  Air Conditioners
# ..            ...               ...
# 175    appliances  Air Conditioners
# 176    appliances  Air Conditioners
# 177    appliances  Air Conditioners
# 178    appliances  Air Conditioners
# 179    appliances  Air Conditioners
#
#                                                  image  \
# 0    https://m.media-amazon.com/images/I/31UISB90sY...
# 1    https://m.media-amazon.com/images/I/51JFb7FctD...
# 2    https://m.media-amazon.com/images/I/51JFb7FctD...
# 3    https://m.media-amazon.com/images/I/51JFb7FctD...
# 4    https://m.media-amazon.com/images/I/41lrtqXPiW...
# ..                                                 ...
# 175  https://m.media-amazon.com/images/I/41H61ZFlBH...
# 176  https://m.media-amazon.com/images/I/717wB+IneG...
# 177  https://m.media-amazon.com/images/I/51h87m-hf-...
# 178  https://m.media-amazon.com/images/I/418VQew9c-...
# 179  https://m.media-amazon.com/images/I/71HYJBEQ7t...
#
#                                                   link ratings no_of_ratings  \
# 0    https://www.amazon.in/Lloyd-Inverter-Convertib...     4.2         2,255
# 1    https://www.amazon.in/LG-Convertible-Anti-Viru...     4.2         2,948
# 2    https://www.amazon.in/LG-Inverter-Convertible-...     4.2         1,206
# 3    https://www.amazon.in/LG-Convertible-Anti-Viru...     4.0            69
# 4    https://www.amazon.in/Carrier-Inverter-Split-C...     4.1           630
# ..                                                 ...     ...           ...
# 175  https://www.amazon.in/Daikin-Inverter-Copper-F...     3.4            31
# 176  https://www.amazon.in/Carrier-Density-Filtrati...     4.0             1
# 177  https://www.amazon.in/Hisense-Inverter-Copper-...     3.9           192
# 178  https://www.amazon.in/Daikin-Inverter-Copper-F...     4.6            40
# 179  https://www.amazon.in/Blue-Star-Compressor-Tec...     NaN           NaN
#
#     discount_price actual_price
# 0          ₹32,999      ₹58,990
# 1          ₹46,490      ₹75,990
# 2          ₹34,490      ₹61,990
# 3          ₹37,990      ₹68,990
# 4          ₹34,490      ₹67,790
# ..             ...          ...
# 175        ₹64,990      ₹86,800
# 176        ₹28,990      ₹39,090
# 177        ₹32,000      ₹45,990
# 178        ₹69,979      ₹92,200
# 179        ₹35,990      ₹45,000
#
# [180 rows x 10 columns]

# %%
# To Check dataset info (columns, data types, missing values)
df.info()
# For checking basic statistics
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551585 entries, 0 to 551584
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      551585 non-null  int64
#  1   name            551585 non-null  object
#  2   main_category   551585 non-null  object
#  3   sub_category    551585 non-null  object
#  4   image           551585 non-null  object
#  5   link            551585 non-null  object
#  6   ratings         375791 non-null  object
#  7   no_of_ratings   375791 non-null  object
#  8   discount_price  490422 non-null  object
#  9   actual_price    533772 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 42.1+ MB
#           Unnamed: 0
# count  551585.000000
# mean     7006.200471
# std      5740.835523
# min         0.000000
# 25%      1550.000000
# 50%      5933.000000
# 75%     11482.000000
# max     19199.000000

# %% [markdown]
# ## 📌 Key Observations
#
# ### 🗑️ Unnecessary Column:
# - `Unnamed: 0` is just an index and can be dropped.
#
# ### 🔄 Data Type Issues:
# - `ratings`, `no_of_ratings`, `discount_price`, and `actual_price` should be numerical but are stored as objects (strings).
#
# ### ⚠️ Missing Values:
# - `ratings` & `no_of_ratings` → **31.8% missing**
# - `discount_price` → **11.1% missing**
# - `actual_price` → **3.2% missing**

# %%
# To handle all the observed issues 
#Drop the Unnamed Column
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# Checking again to veryfy that Unnamed column has been dropped or not
df.head()
# Out:
#                                                 name main_category  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
#
#        sub_category                                              image  \
# 0  Air Conditioners  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  Air Conditioners  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
#                                                 link ratings no_of_ratings  \
# 0  https://www.amazon.in/Lloyd-Inverter-Convertib...     4.2         2,255
# 1  https://www.amazon.in/LG-Convertible-Anti-Viru...     4.2         2,948
# 2  https://www.amazon.in/LG-Inverter-Convertible-...     4.2         1,206
# 3  https://www.amazon.in/LG-Convertible-Anti-Viru...     4.0            69
# 4  https://www.amazon.in/Carrier-Inverter-Split-C...     4.1           630
#
#   discount_price actual_price
# 0        ₹32,999      ₹58,990
# 1        ₹46,490      ₹75,990
# 2        ₹34,490      ₹61,990
# 3        ₹37,990      ₹68,990
# 4        ₹34,490      ₹67,790

# %%
#Rupee sign is persent with prices that can cause an error furthur so first remove it 
df['discount_price'] = df['discount_price'].str.replace('₹','',regex=True)
df['actual_price'] = df['actual_price'].str.replace('₹','',regex=True)

# Remove commas from the 'discount_price' column to ensure it can be converted to a numerical format correctly
df['discount_price'] = df['discount_price'].str.replace(',','',regex=True)
df['actual_price'] = df['actual_price'].str.replace(',','',regex=True)

df.head(181)
# Out:
#                                                   name main_category  \
# 0    Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...    appliances
# 1    LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...    appliances
# 2    LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...    appliances
# 3    LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...    appliances
# 4    Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...    appliances
# ..                                                 ...           ...
# 176  Carrier 1 Ton 3 Star Fixed Speed Window AC(Cop...    appliances
# 177  Hisense 1.0 Ton 5 Star Inverter Split AC (Copp...    appliances
# 178  Daikin 1.8 Ton 5 Star Inverter Split AC (Coppe...    appliances
# 179  Blue Star 1.5 Ton 3 Star Inverter Window AC (C...    appliances
# 180  Hitachi 1 Ton 3 Star Window AC (Copper, Dust F...    appliances
#
#          sub_category                                              image  \
# 0    Air Conditioners  https://m.media-amazon.com/images/I/31UISB90sY...
# 1    Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2    Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3    Air Conditioners  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4    Air Conditioners  https://m.media-amazon.com/images/I/41lrtqXPiW...
# ..                ...                                                ...
# 176  Air Conditioners  https://m.media-amazon.com/images/I/717wB+IneG...
# 177  Air Conditioners  https://m.media-amazon.com/images/I/51h87m-hf-...
# 178  Air Conditioners  https://m.media-amazon.com/images/I/418VQew9c-...
# 179  Air Conditioners  https://m.media-amazon.com/images/I/71HYJBEQ7t...
# 180  Air Conditioners  https://m.media-amazon.com/images/I/7139ds6Ypu...
#
#                                                   link ratings no_of_ratings  \
# 0    https://www.amazon.in/Lloyd-Inverter-Convertib...     4.2         2,255
# 1    https://www.amazon.in/LG-Convertible-Anti-Viru...     4.2         2,948
# 2    https://www.amazon.in/LG-Inverter-Convertible-...     4.2         1,206
# 3    https://www.amazon.in/LG-Convertible-Anti-Viru...     4.0            69
# 4    https://www.amazon.in/Carrier-Inverter-Split-C...     4.1           630
# ..                                                 ...     ...           ...
# 176  https://www.amazon.in/Carrier-Density-Filtrati...     4.0             1
# 177  https://www.amazon.in/Hisense-Inverter-Copper-...     3.9           192
# 178  https://www.amazon.in/Daikin-Inverter-Copper-F...     4.6            40
# 179  https://www.amazon.in/Blue-Star-Compressor-Tec...     NaN           NaN
# 180  https://www.amazon.in/Hitachi-Window-Copper-Fi...     4.1           101
#
#     discount_price actual_price
# 0            32999        58990
# 1            46490        75990
# 2            34490        61990
# 3            37990        68990
# 4            34490        67790
# ..             ...          ...
# 176          28990        39090
# 177          32000        45990
# 178          69979        92200
# 179          35990        45000
# 180            NaN          NaN
#
# [181 rows x 9 columns]

# %%
# Now to handle Data Type issue
# Convert ratings to float (ratings usually have decimal values)
df['ratings'] = pd.to_numeric(df['ratings'], errors='coerce').astype(float)
# Convert no_of_ratings, discount_price, and actual_price to integers & handling not a number values with memory optimization
df['no_of_ratings'] = pd.to_numeric(df['no_of_ratings'],errors='coerce').fillna(0).astype(np.int32)
df['discount_price'] = pd.to_numeric(df['discount_price'],errors='coerce').fillna(0).astype(np.int32)
df['actual_price'] = pd.to_numeric(df['actual_price'],errors='coerce').fillna(0).astype(np.int32)

# %%
# Verify the changes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551585 entries, 0 to 551584
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            551585 non-null  object
#  1   main_category   551585 non-null  object
#  2   sub_category    551585 non-null  object
#  3   image           551585 non-null  object
#  4   link            551585 non-null  object
#  5   ratings         369558 non-null  float64
#  6   no_of_ratings   551585 non-null  int32
#  7   discount_price  551585 non-null  int32
#  8   actual_price    551585 non-null  int32
# dtypes: float64(1), int32(3), object(5)
# memory usage: 31.6+ MB

# %%
#After sorting this issue next 
#Checking for the outliers in different-different columns
#Checking for negative or extreme values in pricing
print("Min Discount Price:", df['discount_price'].min())
print("Max Discount Price:",df['discount_price'].max())
print("Min Actual Price:",df['actual_price'].min())
print("Max Actual Price:",df['actual_price'].max())
# Checking for unreal ratings
print("Min Rating:",df['ratings'].min())
print("Max Rating:",df['ratings'].max())
# Out:
# Min Discount Price: 0
# Max Discount Price: 1249990
# Min Actual Price: 0
# Max Actual Price: 2147483647
# Min Rating: 1.0
# Max Rating: 5.0

# %% [markdown]
# #### **Pricing Analysis**
# - **Minimum Discount Price:** 0
# - **Maximum Discount Price:** 1,249,990 (Unrealistically high)
# - **Minimum Actual Price:** 0  (Unrealistically)
# - **Maximum Actual Price:** 9900000000 (Unrealistically high)
#
# #### **Ratings Analysis**
# - **Minimum Rating:** 1.0
# - **Maximum Rating:** 5.0 (Within expected range)
#
#  **Observations:**
# - The **maximum actual price** & **Maximum Discount Price:** appears suspiciously high, potentially an outlier.
# - The **Minimum Actual Price** is 0 that's

# %%
# Set a threshold for extreme prices
extreme_actual_price = df[df['actual_price'] > 1000000]
extreme_discount_price = df[df['discount_price'] > 500000]

# Display the count of extreme values
print("Number of extreme actual prices:", extreme_actual_price.shape[0])
print("Number of extreme discount prices:", extreme_discount_price.shape[0])
# Out:
# Number of extreme actual prices: 7
# Number of extreme discount prices: 1

# %%
# Display some extreme actual price values
print("Extreme Actual Price Products:")
display(extreme_actual_price[['name', 'actual_price', 'discount_price']].head(10))

# Display some extreme discount price values
print("Extreme Discount Price Products:")
display(extreme_discount_price[['name', 'actual_price', 'discount_price']].head(10))
#verify the prices
# Out:
# Extreme Actual Price Products:
#                                                      name  actual_price  \
# 194625  Marutivilla Insect Killer, Mosquito Killer Lig...  9.900000e+09
# 311949  USPTO डायमंड वन स्टोन D Colour Genuine 3 Carat...  1.200000e+06
# 334263  USPTO डायमंड वन स्टोन D Colour Genuine 3 Carat...  1.200000e+06
# 390319  USPTO डायमंड वन स्टोन D Colour Genuine 3 Carat...  1.200000e+06
# 390351  USPTO डायमंड वन स्टोन D Colour Genuine 3 Carat...  1.200000e+06
# 402750  Clovia Women's Activewear Ankle Length Printed...  6.108299e+07
# 498818  Samsung 214 cm (85 inches) 8K Ultra HD Smart N...  1.594900e+06
#
#         discount_price
# 194625           589.0
# 311949        406009.0
# 334263        406009.0
# 390319        406009.0
# 390351        406009.0
# 402750           688.0
# 498818       1249990.0
# Extreme Discount Price Products:
#                                                      name  actual_price  \
# 498818  Samsung 214 cm (85 inches) 8K Ultra HD Smart N...     1594900.0
#
#         discount_price
# 498818       1249990.0

# %%
#Fix the incorrect discount price for the Samsung TV
#The actual price is legitimate, but the discount price has an extra zero (1249990 instead of 124999).
df.loc[df['name'].str.contains("Samsung 214 cm", case=False, na=False), 'discount_price'] = 124999

# Remove products with unrealistic actual prices
# The "Marutivilla Insect Killer" and "USPTO Diamond" products have incorrect pricing, so we remove them.
df = df[~df['name'].isin([
    "Marutivilla Insect Killer, Mosquito Killer Lig...",
    "USPTO डायमंड वन स्टोन D Colour Genuine 3 Carat..."
])]

# %%
#Verify the fixes
print("Min Discount Price:", df['discount_price'].min())
print("Max Discount Price:",df['discount_price'].max())
print("Min Actual Price:",df['actual_price'].min())
print("Max Actual Price:",df['actual_price'].max())
# Out:
# Min Discount Price: 0.0
# Max Discount Price: 499999.0
# Min Actual Price: 0.0
# Max Actual Price: 9900000000.0

# %%
zero_price_products = df[(df['actual_price'] == 0) & (df['discount_price'] == 0)]
print(f"Number of products with both actual price and discount price as 0: {len(zero_price_products)}")
print(zero_price_products.shape[0])  # Display first 10 rows
# Out:
# Number of products with both actual price and discount price as 0: 17815
# 17815

# %%
from IPython.display import display

# Select products where both actual_price and discount_price are zero
zero_price_products = df[(df['actual_price'] == 0) & (df['discount_price'] == 0)]

# Display first 20 rows in tabular format
display(zero_price_products.head(20))
# Out:
#                                                   name main_category  \
# 76   LG 1.5 Ton 3 Star Hot & Cold DUAL Inverter Spl...    appliances
# 100  Hitachi 1.5 Ton 5 Star Inverter Split AC (Copp...    appliances
# 114  Panasonic 1.5 Ton 4 Star Wi-Fi Twin-Cool Inver...    appliances
# 144  Daikin 1.5 Ton 4 Star Hot & Cold Heat Pump Inv...    appliances
# 146  LG 1.5 Ton 5 Star AI DUAL Inverter Wi-Fi Split...    appliances
# 170  Blue Star 2 Tr 3 Star Fixed Speed Split AC (Co...    appliances
# 180  Hitachi 1 Ton 3 Star Window AC (Copper, Dust F...    appliances
# 181  Daikin 1.5 Ton 5 Star Dust Filter Window AC (C...    appliances
# 196  Godrej 1 Ton 3 Star Inverter Split AC (Copper,...    appliances
# 200  Panasonic 1.5 Ton 3 Star Window AC (Copper, PM...    appliances
# 206  Daikin 1.5 Ton 3 Star Dust Filter Window AC (C...    appliances
# 214  LG 1.5 Ton 5 Star Wi-Fi Inverter Split AC (Cop...    appliances
# 218  Whirlpool 1.5 Ton 5 Star Inverter Split AC (Co...    appliances
# 221  Lloyd Havells 1.5 Ton 3 Star Window Ac (Copper...    appliances
# 228  Voltas Adjustable Inverter AC, 1.5 Ton, 3 Star...    appliances
# 238  Carrier Emperia CXI Wifi 1.5 Ton 5 Star Invert...    appliances
# 239  Panasonic 2 Ton Hot and Cold Wi-Fi Inverter 3 ...    appliances
# 240  Haier 1.5 Ton 3 Star Antibacterial Coating, Du...    appliances
# 251  Daikin 1.5 Ton 5 Star Inverter Split AC (Coppe...    appliances
# 252  Panasonic 2.2 Ton Inverter 3 Star Split Smart ...    appliances
#
#          sub_category                                              image  \
# 76   Air Conditioners  https://m.media-amazon.com/images/I/51hbo8yQ1E...
# 100  Air Conditioners  https://m.media-amazon.com/images/I/41AY1pk5oR...
# 114  Air Conditioners  https://m.media-amazon.com/images/I/41Edvsb7Gh...
# 144  Air Conditioners  https://m.media-amazon.com/images/W/IMAGERENDE...
# 146  Air Conditioners  https://m.media-amazon.com/images/W/IMAGERENDE...
# 170  Air Conditioners  https://m.media-amazon.com/images/I/21WQrs98j1...
# 180  Air Conditioners  https://m.media-amazon.com/images/I/7139ds6Ypu...
# 181  Air Conditioners  https://m.media-amazon.com/images/I/7125Imt+0z...
# 196  Air Conditioners  https://m.media-amazon.com/images/I/31lenJuVeA...
# 200  Air Conditioners  https://m.media-amazon.com/images/I/61E911ntaK...
# 206  Air Conditioners  https://m.media-amazon.com/images/I/61Kn2QYI1a...
# 214  Air Conditioners  https://m.media-amazon.com/images/I/511CwCjVTF...
# 218  Air Conditioners  https://m.media-amazon.com/images/W/IMAGERENDE...
# 221  Air Conditioners  https://m.media-amazon.com/images/W/IMAGERENDE...
# 228  Air Conditioners  https://m.media-amazon.com/images/W/IMAGERENDE...
# 238  Air Conditioners  https://m.media-amazon.com/images/W/IMAGERENDE...
# 239  Air Conditioners  https://m.media-amazon.com/images/W/IMAGERENDE...
# 240  Air Conditioners  https://m.media-amazon.com/images/W/IMAGERENDE...
# 251  Air Conditioners  https://m.media-amazon.com/images/W/IMAGERENDE...
# 252  Air Conditioners  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                   link  ratings  \
# 76   https://www.amazon.in/LG-Inverter-Convertible-...      4.0
# 100  https://www.amazon.in/Hitachi-Inverter-Copper-...      3.8
# 114  https://www.amazon.in/Panasonic-Conditioner-An...      4.5
# 144  https://www.amazon.in/Daikin-Inverter-Conditio...      3.7
# 146  https://www.amazon.in/LG-Inverter-Convertible-...      4.7
# 170  https://www.amazon.in/Blue-Star-Fixed-Copper-F...      NaN
# 180  https://www.amazon.in/Hitachi-Window-Copper-Fi...      4.1
# 181  https://www.amazon.in/Daikin-1-5-Ton-Star-Wind...      4.1
# 196  https://www.amazon.in/Godrej-Inverter-Copper-A...      3.8
# 200  https://www.amazon.in/Panasonic-Window-Copper-...      4.2
# 206  https://www.amazon.in/Daikin-1-5-Ton-Star-Wind...      3.9
# 214  https://www.amazon.in/LG-Inverter-Convertible-...      4.4
# 218  https://www.amazon.in/Whirlpool-1-5T-SUPREMECO...      2.9
# 221  https://www.amazon.in/Lloyd-Window-Copper-Filt...      4.2
# 228  https://www.amazon.in/Voltas-Adjustable-Invert...      NaN
# 238  https://www.amazon.in/Carrier-Emperia-CXI-Cond...      NaN
# 239  https://www.amazon.in/Panasonic-Inverter-Coppe...      3.3
# 240  https://www.amazon.in/Haier-Split-Copper-HSU18...      4.0
# 251  https://www.amazon.in/Daikin-Inverter-Copper-F...      4.2
# 252  https://www.amazon.in/PANASONIC-CS-CU-QU26YKY-...      5.0
#
#      no_of_ratings  discount_price  actual_price
# 76             265             0.0           0.0
# 100            748             0.0           0.0
# 114            195             0.0           0.0
# 144             27             0.0           0.0
# 146             34             0.0           0.0
# 170              0             0.0           0.0
# 180            101             0.0           0.0
# 181             96             0.0           0.0
# 196             51             0.0           0.0
# 200            567             0.0           0.0
# 206             62             0.0           0.0
# 214            769             0.0           0.0
# 218             10             0.0           0.0
# 221            329             0.0           0.0
# 228              0             0.0           0.0
# 238              0             0.0           0.0
# 239              5             0.0           0.0
# 240            302             0.0           0.0
# 251             12             0.0           0.0
# 252              2             0.0           0.0
